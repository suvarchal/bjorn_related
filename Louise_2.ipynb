# %%
import xarray as xr
import

# %%
ds=xr.open_mfdataset('BCO_DWL/*.nc')

# %%
U = ds['U']
V = ds['V']
z = ds['Height']
t = ds['Time']
U1 = U.isel(SNR_threshold=0)
V1 = V.isel(SNR_threshold=0)

# %%
U1.rolling(Time=3,center=True).mean(dim='Time')
# Out:
# <xarray.DataArray 'getitem-fac0a03cc4718eb10745a7a02ac33cec' (Height: 100, Time: 4538)>
# dask.array<shape=(100, 4538), dtype=float64, chunksize=(100, 4538)>
# Coordinates:
#   * Height         (Height) float64 15.0 45.0 75.0 105.0 135.0 165.0 195.0 ...
#     SNR_threshold  int64 -16
#   * Time           (Time) datetime64[ns] 2016-02-01T04:13:01.789999872 ...

# %%
# %matplotlib inline

# %%
U1_sm=U1.rolling(Time=10,center=True).mean(dim='Time')

# %%
U1_sm.plot.contourf()

# %%
U1.plot.contourf()

# %%
U1.sel(Height=200,method='nearest').plot.line()

# %%
U1_sm.sel(Height=200,method='nearest').plot.line()

# %%
da.resample(Time='2H').mean().U.sel(SNR_threshold=0,Height=200,method='nearest').plot.line()
# Out:
# /home/suvarchal/miniconda3/envs/default/lib/python3.6/site-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
